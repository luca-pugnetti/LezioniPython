# %% [markdown]
# # **Esercizio 1**
# 1. Cosa succede se scrivete x = y = 1?
# 2. Cosa succede se mettete un punto e virgola alla fine di un’istruzione in Python in Colab?
# 3. Nella notazione matematica potete indicare la moltiplicazione di x per y scrivendo: xy. Cosa succede scrivendo questo in
# Python?

# %%
x = y = 1
x
y
# Out:
# 1

# %%
y;

# %%
x*y
# Out:
# 1

# %% [markdown]
# # **Esercizio 2**
# 1. Il volume di una sfera di raggio r è
# $4/3𝜋𝑟^3$. Che volume ha una sfera di raggio 5?
# 2. Il prezzo di copertina di un libro è 24,95 euro, ma una libreria ottiene il 40% di sconto. I costi di spedizione sono 3 euro
# per la prima copia e 75 centesimi per ogni copia aggiuntiva. Qual è il costo totale di 60 copie?
# 3. Se uscite di casa alle 6:52 di mattina e correte 1 miglio a ritmo blando (8:15 al miglio), poi 3 miglia a ritmo moderato
# (7:12 al miglio), quindi 1 altro miglio a ritmo blando, a che ora tornate a casa per colazione?

# %%
import math

raggio = 5 # raggio della sfera
volume = 4/3 * math.pi * raggio**3
print(volume)
# Out:
# 523.5987755982989

# %%
prezzo_libro = 24.95
sconto = 0.4
costi_spedizione_1 = 3
costi_spedizione_succ = 0.75
n_copie = 60

prezzo_finale = (prezzo_libro - prezzo_libro * sconto)*n_copie + costi_spedizione_1 + costi_spedizione_succ * (n_copie-1)

print(prezzo_finale)
# Out:
# 945.4499999999999

# %%
# orario di uscita in secondi
orario_uscita = (6 * 3600) + (52 * 60)

# ritmi in secondi
ritmo_blando = 8 * 60 + 15
ritmo_moderato = 7 * 60 + 12

# tempo totale di corsa
tempo_totale_corsa = (2 * ritmo_blando) + (3 * ritmo_moderato)

# orario di rientro in secondi
orario_rientro = orario_uscita + tempo_totale_corsa

# conversione in ore e minuti

# siccome 1 ora = 3600 sec --> la divisione intera dell'orario di rientro (in secondi) per 3600 ci darà il numero di ore
ore_rientro = orario_rientro // 3600

# ora analizziamo il resto della divisione per 3600 e ci darà la parte di ora non ancora utilizzata e dividendola (tramite
# divisione intera) per 60 otteniamo il numero di minuti
minuti_rientro = (orario_rientro % 3600) // 60

print("Orario rientro: {:02}:{:02}".format(ore_rientro, minuti_rientro))
# Out:
# Orario rientro: 07:30
