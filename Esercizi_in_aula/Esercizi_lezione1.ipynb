# %% [markdown]
# ![immagine.png](data:image/png;base64,...)

# %%
# (1)
#print('Ciao'
#print'Ciao')
#print'Ciao'

# Errori di sintassi (differenti)

# %%
# (2)
#print(Ciao')
#print(Ciao)

# Errore di sintassi + NameError

# %%
#(3)
#-2
#+2
#2++2
2-+2

# nessun errore, il + davanti a un numero significa che il numero è positivo
# Out:
# 0

# %%
# (4)
#02

#Errore, usare 0o per ottale e 0x per esadecimale
# Out:
# 13

# %%
# (5)
#5 6

#Errore, non utilizzare

# %% [markdown]
# ![immagine.png](data:image/png;base64,...)

# %%
# (1)
42 + 42 * 60
# Out:
# 2562

# %%
# (2)
10 / 1.61
# Out:
# 6.211180124223602

# %%
# (3)
print('Tempo al miglio in secondi', 2562 / (10 / 1.61))
print('Tempo al miglio in minuti', round(2562 / (10 / 1.61) / 60, 3))

2562/3600 # tempo in ore

print('Velocità media oraria', round((10 / 1.61) / 2562 * 3600,3))
# Out:
# Tempo al miglio in secondi 412.482
# Tempo al miglio in minuti 6.875
# Velocità media oraria 8.728
