# %% [markdown]
# # **Esercizio 1: Calcolo dell'Indice di Massa Corporea (BMI).**
#
# Crea una funzione `calcola_bmi` che calcola l’indice di massa corporea (BMI) di una persona.
#
# La funzione accetta due argomenti: `peso` (in chilogrammi) e `altezza` (in metri).
# Restituisce il valore del BMI calcolato con la formula:
#
# BMI = $ \large \frac{peso}{altezza^2} $
# ​
#
# Assicurati di convertire il risultato in un numero con una precisione di due cifre decimali.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 2: Calcolo della Distanza tra Due Punti**
#
# Crea una funzione `distanza` che calcola la distanza euclidea tra due punti su un piano cartesiano.
#
# La funzione accetta quattro argomenti, `x1`, `y1`, `x2`, `y2`, che rappresentano le coordinate dei due punti.
# Restituisce la distanza calcolata con la formula:
#
# $ distanza = \sqrt{(x2 - x1)^2 + (y2 - y1)^2}$​
#
# Utilizza `math.sqrt` per calcolare la radice quadrata e ritorna un valore con almeno due cifre decimali.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 2: Calcolo dello Stato dell'Acqua**
# Crea una funzione `stato_acqua` che determina lo stato dell’acqua (solido, liquido, gassoso) a una determinata temperatura.
#
# La funzione accetta un argomento `temperatura`, un numero che rappresenta la temperatura in gradi Celsius.
# La funzione restituisce:
# - "Solido" se la temperatura è inferiore o uguale a 0°C.
# - "Liquido" se è tra 0°C e 100°C.
# - "Gassoso" se è maggiore o uguale a 100°C.\
#
# Usa `if`-`elif`-`else` per valutare la condizione.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 3: Controllo di Triangolo**
# Crea una funzione `tipo_triangolo` che classifica un triangolo in base alle lunghezze dei suoi lati.
#
# La funzione accetta tre argomenti, lato1, lato2 e lato3, che rappresentano le lunghezze dei lati.
# Restituisci:
# - "Equilatero" se tutti i lati sono uguali.
# - "Isoscele" se esattamente due lati sono uguali.
# - "Scaleno" se tutti i lati sono diversi.\
#
# Usa `if`-`elif`-`else` per fare le valutazioni.

# %%
# Soluzione...
