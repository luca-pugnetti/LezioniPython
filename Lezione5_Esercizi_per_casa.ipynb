# %% [markdown]
# # **Esercizio 1**
#
# Scrivere un programma che calcoli il fattoriale di un numero intero. Il fattoriale di un numero intero positivo $n$ si scrive $n!$ ($n$ fattoriale) ed è definito così: $n! = n · (n – 1) · (n – 2) · … · 1$ per tutti i valori di $n$ maggiori o uguali a $1$; per definizione, $0!$ è uguale a $1$.\
# Quindi, $5!= 5· 4· 3· 2· 1$ che fa $120$.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 2**
#
# Si sviluppi un programma che chiede all'utente di inserire una serie di numeri interi, uno alla volta. Il programma deve continuare a ricevere numeri finché l'utente non inserisce il numero 0, il quale indica che l'inserimento è terminato. Alla fine, il programma deve calcolare e stampare la somma dei numeri pari inseriti dall'utente.

# %%
# Soluzione
