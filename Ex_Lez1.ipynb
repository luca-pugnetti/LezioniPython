# %% [markdown]
# # **Esercizio 1: Operatori aritmetici**
#
# Si scriva un'espressione che calcoli la somma del quadrato di 5 e la moltiplicazione di 8 e 3, poi dividi il risultato per 2. Qual è il valore finale?

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 2: Divisione intera**
#
# Si utilizzi l'operatore di divisione intera `//` per calcolare quante volte il numero 13 entra in 100. Qual è il risultato?

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 3: Lunghezza di una stringa**
#
# Si crei una stringa che rappresenti una frase a scelta (ad esempio, "Ciao, come stai?"). Si utilizzi la funzione `len()` per determinare la lunghezza della stringa. Qual è la lunghezza della frase? Se poi si contano i caratteri della frase manualmente corrispondono alla lunghezza calcolata dalla funzione `len()`?

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 4: Concatenazione di stringhe**
#
# Si scrivano due stringhe: una che contenga "Buongiorno" e un'altra che contenga "Mondo!". Si concatenino insieme usando l'operatore `+` per ottenere il risultato "Buongiorno, Mondo!".

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 5: Conversione di tipi**
#
# Si dispone di una stringa che contiene il numero "75". Si moltiplichi tale stringa per 3. Successivamente, si converta questa stringa in un intero usando la funzione `int()`, e poi si moltiplichi il risultato per 3. Qual è il valore finale?
#
# Siccome nel caso di più operazioni, all'interno dello stesso blocco di codice, verrà stamapto soltanto il risultato dell'ultima (provare per credere). Invito ad inserire le operazioni precedenti all'interno della funzione `display()` per visualizzarne il risultato.

# %%
"75"*3

int(75)*3;
