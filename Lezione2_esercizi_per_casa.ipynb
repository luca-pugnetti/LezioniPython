# %% [markdown]
# # **Esercizio 1: Scambio di Valori**
#
# Si scriva del codice che scambi i valori di due variabili. Crea due variabili `a` e `b` con i valori iniziali 5 e 10, rispettivamente. Scambia i loro valori e poi visualizza i risultati.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 2: Uso di Variabili e Operatori**
#
# Si scriva del codice che assegni a due variabili intere `x` e `y` dei valori. Si eseguano operazioni aritmetiche su queste variabili, come somma, sottrazione, moltiplicazione e divisione. Successivamente, si assegni il risultato di ciascuna operazione a nuove variabili e si visualizzino i risultati.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 3: Calcolo del Volume di una Sfera**
#
# Si calcoli il volume di una sfera con raggio 7 cm utilizzando la formula $V = \frac{4}{3} \pi r^3$. Si assegni il risultato a una variabile volume e si aggiungano commenti che spieghino i calcoli. Infine, si visualizzi il risultato.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 4: Verifica della Relazione Seno e Coseno**
#
# Si verifichi la relazione $\sin^2(x) + \cos^2(x) = 1$ per un angolo di un numero casuale `r` di gradi. Si utilizzino le funzioni `math.rand()`, `math.radians()`, `math.sin()` e `math.cos()` per calcolare il risultato e si visualizzi il valore della somma.
# `math.radians()` la si utilizza perchè gli angoli su cui lavorano seno e coseno sono in radianti Per verificare `help(math.sin)`.

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 5: Verifica dell'Esponenziale**
#
# Si calcoli $e^2$ in tre modi diversi: utilizzando l'operatore `**`, la funzione `math.pow()`, e la funzione `math.exp()`. Si confrontino i risultati ottenuti e si verifichi se vi sono differenze significative. Se non si ricorda il corretto utilizzo delle funzioni citate `help(nome_funzione_senza_parentesi)`.

# %%
# Soluzione...
