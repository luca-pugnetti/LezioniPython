# %% [markdown]
# # **Esercizio 1**
#
# Scrivere un programma che operi sulle liste di stringhe.\
#  Si chieda all'utente quante stringhe voglia inserire e successivamente si controlli quante stringhe di almeno 3 caratteri abbiano primo e ultimo carattere uguali.
#
# Esempio:\
# lista_stringhe : ['abc', 'xyz', 'aba', '1221']\
# Risultato : 2

# %%
# Soluzione...

# %% [markdown]
# # **Esercizio 2**
#
# Scrivi una funzione ricorsiva che calcola la somma ponderata degli elementi di una lista di numeri interi. Ogni elemento della lista deve essere moltiplicato per un "peso" che è determinato dalla sua posizione nella lista, ma con l'indice incrementato di 1 (ovvero, il primo elemento ha peso 1, il secondo ha peso 2, e così via).
#
# Indicazioni:
# 1. La funzione deve ricevere un solo argomento: una lista di numeri interi lista.
# 2. Ogni elemento della lista deve essere moltiplicato per il suo indice nella lista + 1.
# 3. La funzione deve restituire la somma ponderata di tutti gli elementi.
# 4. Se la lista è vuota, la funzione deve restituire 0.
# La funzione deve essere ricorsiva e calcolare la somma pesata degli elementi

# %%
# Soluzione...
